# %% [markdown]
# # Arche — AR vs MDLM Experiment
# Train and compare Autoregressive vs Masked Diffusion Language Models.
#
# 1. Runtime > Change runtime type > **GPU (T4)**
# 2. Run all cells

# %%
# !pip install -q transformers datasets tqdm

# %%
import torch
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    vram = torch.cuda.get_device_properties(0).total_mem / 1e9
    print(f'VRAM: {vram:.1f} GB')
else:
    print('NO GPU! Go to Runtime > Change runtime type > GPU')

# %%
# Upload arche_colab.py from your Mac
from google.colab import files
uploaded = files.upload()  # Click 'Choose Files' and select arche_colab.py

# %%
# Run the full experiment
# !python arche_colab.py

# %%
# Download results when done
from google.colab import files
files.download('results.json')
